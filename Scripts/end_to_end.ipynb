# %%
import os
import sys
sys.path.append('/home/shanwibo/Capstone-TamTanai')

import warnings
warnings.filterwarnings('ignore')

import pandas as pd
from tqdm import tqdm

from src.main import LegalAssistant

# %%
df = pd.read_csv('../asset/dataset/new_testdataset_1.csv')
df
# Out:
#      Column1                                         knowledges  \
# 0          0  ประมวลกฎหมายยาเสพติด - ภาค 1 (การป้องกัน ปราบป...
# 1          1  พระราชบัญญัติให้ใช้ประมวลกฎหมายยาเสพติด พ.ศ. 2...
# 2          2  ประมวลกฎหมายยาเสพติด - ภาค 1 (การป้องกัน ปราบป...
# 3          3  ประมวลกฎหมายยาเสพติด - ภาค 1 (การป้องกัน ปราบป...
# 4          4  ประมวลกฎหมายยาเสพติด - ภาค 1 (การป้องกัน ปราบป...
# ..       ...                                                ...
# 408      408  พระราชบัญญัติภาษีที่ดินและสิ่งปลูกสร้าง พ.ศ. 2...
# 409      409  พระราชบัญญัติภาษีที่ดินและสิ่งปลูกสร้าง พ.ศ. 2...
# 410      410  พระราชบัญญัติภาษีที่ดินและสิ่งปลูกสร้าง พ.ศ. 2...
# 411      411  พระราชบัญญัติว่าด้วยข้อสัญญาที่ไม่เป็นธรรม พ.ศ...
# 412      412  พระราชบัญญัติว่าด้วยข้อสัญญาที่ไม่เป็นธรรม พ.ศ...
#
#                                             law  \
# 0                          ประมวลกฎหมายยาเสพติด
# 1                          ประมวลกฎหมายยาเสพติด
# 2                          ประมวลกฎหมายยาเสพติด
# 3                          ประมวลกฎหมายยาเสพติด
# 4                          ประมวลกฎหมายยาเสพติด
# ..                                          ...
# 408     พระราชบัญญัติภาษีที่ดินและสิ่งปลูกสร้าง
# 409     พระราชบัญญัติภาษีที่ดินและสิ่งปลูกสร้าง
# 410     พระราชบัญญัติภาษีที่ดินและสิ่งปลูกสร้าง
# 411  พระราชบัญญัติว่าด้วยข้อสัญญาที่ไม่เป็นธรรม
# 412  พระราชบัญญัติว่าด้วยข้อสัญญาที่ไม่เป็นธรรม
#
#                                                 source  \
# 0    ประมวลกฎหมายยาเสพติด/ประมวลกฎหมายยาเสพติด_ภาค1...
# 1    ประมวลกฎหมายยาเสพติด/ประมวลกฎหมายยาเสพติด_บทนำ...
# 2    ประมวลกฎหมายยาเสพติด/ประมวลกฎหมายยาเสพติด_ภาค1...
# 3    ประมวลกฎหมายยาเสพติด/ประมวลกฎหมายยาเสพติด_ภาค1...
# 4    ประมวลกฎหมายยาเสพติด/ประมวลกฎหมายยาเสพติด_ภาค1...
# ..                                                 ...
# 408  พระราชบัญญัติภาษีที่ดินและสิ่งปลูกสร้าง/พระราช...
# 409  พระราชบัญญัติภาษีที่ดินและสิ่งปลูกสร้าง/พระราช...
# 410  พระราชบัญญัติภาษีที่ดินและสิ่งปลูกสร้าง/พระราช...
# 411  พระราชบัญญัติว่าด้วยข้อสัญญาที่ไม่เป็นธรรม/พระ...
# 412  พระราชบัญญัติว่าด้วยข้อสัญญาที่ไม่เป็นธรรม/พระ...
#
#                                               question  \
# 0    คณะกรรมการควบคุมยาเสพติดประกอบด้วยใครบ้างตามมา...
# 1    ผู้รับอนุญาตที่มีใบอนุญาตเกี่ยวกับยาเสพติดก่อน...
# 2    คณะกรรมการตรวจสอบทรัพย์สินตามประมวลกฎหมายยาเสพ...
# 3    พนักงานเจ้าหน้าที่สามารถดำเนินการอะไรได้บ้างเม...
# 4       การนำเข้าหรือส่งออกยาเสพติดให้โทษต้องทำอย่างไร
# ..                                                 ...
# 408  หากผู้กระทำผิดตามมาตรา 83, 84, 85 หรือ 87 ไม่ย...
# 409  พระราชบัญญัติภาษีที่ดินและสิ่งปลูกสร้าง พ.ศ. 2...
# 410  หากผู้เสียภาษีชำระภาษีก่อนจะได้รับหนังสือแจ้งเ...
# 411  ข้อตกลงในสัญญาเช่าซื้อที่กำหนดราคาค่าเช่าซื้อส...
# 412  ข้อตกลงที่ให้สิทธิบอกเลิกสัญญาได้โดยอีกฝ่ายหนึ...
#
#                                                 answer  \
# 0    คณะกรรมการควบคุมยาเสพติดประกอบด้วย ปลัดกระทรวง...
# 1    สามารถดำเนินกิจการต่อไปได้จนกว่าใบอนุญาตนั้นสิ...
# 2    คณะกรรมการตรวจสอบทรัพย์สินประกอบด้วย ปลัดกระทร...
# 3    พนักงานเจ้าหน้าที่สามารถยึดหรืออายัดยาเสพติดที...
# 4    ต้องได้รับใบอนุญาตเฉพาะคราวจากผู้อนุญาตทุกครั้...
# ..                                                 ...
# 408                                  ให้ดำเนินคดีต่อไป
# 409  พระราชบัญญัตินี้ให้ใช้บังคับตั้งแต่วันถัดจากวั...
# 410     ต้องเสียเบี้ยปรับร้อยละสิบของจำนวนภาษีค้างชำระ
# 411                       ถือเป็นข้อตกลงที่ไม่เป็นธรรม
# 412                       ถือเป็นข้อตกลงที่ไม่เป็นธรรม
#
#                                                 prompt
# 0    <s><|im_start|>system\nคุณคือนักกฎหมายที่จะตอบ...
# 1    <s><|im_start|>system\nคุณคือนักกฎหมายที่จะตอบ...
# 2    <s><|im_start|>system\nคุณคือนักกฎหมายที่จะตอบ...
# 3    <s><|im_start|>system\nคุณคือนักกฎหมายที่จะตอบ...
# 4    <s><|im_start|>system\nคุณคือนักกฎหมายที่จะตอบ...
# ..                                                 ...
# 408  <s><|im_start|>system\nคุณคือนักกฎหมายที่จะตอบ...
# 409  <s><|im_start|>system\nคุณคือนักกฎหมายที่จะตอบ...
# 410  <s><|im_start|>system\nคุณคือนักกฎหมายที่จะตอบ...
# 411  <s><|im_start|>system\nคุณคือนักกฎหมายที่จะตอบ...
# 412  <s><|im_start|>system\nคุณคือนักกฎหมายที่จะตอบ...
#
# [413 rows x 7 columns]

# %%
n_documents = 1

INFERENCE_RESULT_PATH = f'/project/lt200301-edubot/Capstone-TamTanai/inference_result/inference_end_to_end_n_documents={n_documents}.csv'

if n_documents == 1:
    max_input_tokens = 8192
elif n_documents <= 2:
    max_input_tokens = 8192 * 2
else:
    max_input_tokens = 8192 * 4

# %%
legal_assistant = LegalAssistant(
    max_input_tokens=max_input_tokens,
    top_p=0.9,
    temperature=0.1,
    repetition_penalty=1.1,
    max_new_tokens=512
)
# Out:
# ----------using 4*GPUs----------
# Loading checkpoint shards: 100%|██████████| 4/4 [00:08<00:00,  2.06s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:08<00:00,  2.05s/it]

# %%
result_df = []
for _, row in tqdm(df.iloc[:1].iterrows(), total=df.iloc[:1].shape[0]):
    result = legal_assistant(row['question'], n_documents=n_documents)
    if result['retrieval'] is None:
        del result['retrieval']
    result = pd.json_normalize(result, sep='_').to_dict(orient='records')[0]
    result.update({
        'question': row['question'],
        'answer': row['answer']
    })
    result_df.append(result)
result_df = pd.DataFrame(result_df)
result_df = result_df[['question', 'answer', 'processing_time', 'domain_detection_result', 'domain_detection_probability',
                       'domain_detection_time_usage', 'retrieval_result', 'retrieval_source', 'retrieval_reranking_score', 'retrieval_time_usage',
                       'generation_result', 'generation_time_usage']]
result_df
# Out:
# 100%|██████████| 1/1 [00:42<00:00, 42.39s/it]
#                                             question  \
# 0  คณะกรรมการควบคุมยาเสพติดประกอบด้วยใครบ้างตามมา...
#
#                                               answer  processing_time  \
# 0  คณะกรรมการควบคุมยาเสพติดประกอบด้วย ปลัดกระทรวง...        42.389346
#
#    domain_detection_result  domain_detection_probability  \
# 0                     True                      0.999814
#
#    domain_detection_time_usage  \
# 0                     0.007294
#
#                                     retrieval_result  \
# 0  [ประมวลกฎหมายยาเสพติด - ภาค 1 (การป้องกัน ปราบ...
#
#                                     retrieval_source  \
# 0  [/home/shanwibo/Capstone-TamTanai/asset/docume...
#
#   retrieval_reranking_score  retrieval_time_usage  \
# 0      [0.9999998115390829]               0.11757
#
#                                    generation_result  generation_time_usage
# 0  คณะกรรมการควบคุมยาเสพติดประกอบด้วยปลัดกระทรวงส...              42.264432

# %%
result_df = []
for _, row in tqdm(df.iloc[:2].iterrows(), total=df.iloc[:2].shape[0]):
    result = legal_assistant(row['question'], n_documents=n_documents)
    if result['retrieval'] is None:
        del result['retrieval']
    result = pd.json_normalize(result, sep='_').to_dict(orient='records')[0]
    result.update({
        'question': row['question'],
        'answer': row['answer']
    })
    result_df.append(result)
result_df = pd.DataFrame(result_df)
result_df = result_df[['question', 'answer', 'processing_time', 'domain_detection_result', 'domain_detection_probability',
                       'domain_detection_time_usage', 'retrieval_result', 'retrieval_reranking_score', 'retrieval_time_usage',
                       'generation_result', 'generation_time_usage']]
result_df
# Out:
# 100%|██████████| 2/2 [01:40<00:00, 50.16s/it]
#                                             question  \
# 0  ตามพระราชบัญญัติขายตรงและตลาดแบบตรง พ.ศ. 2545 ...
# 1  หากลูกหนี้ไม่ได้กำหนดเวลาชำระหนี้ไว้ ลูกหนี้สา...
#
#                                               answer  processing_time  \
# 0  'สินค้า' หมายความว่า สิ่งของที่ผลิตหรือมีไว้เพ...        44.589779
# 1                    ลูกหนี้สามารถชำระหนี้ได้โดยพลัน        55.735389
#
#    domain_detection_result  domain_detection_probability  \
# 0                     True                      0.999809
# 1                     True                      0.999805
#
#    domain_detection_time_usage  \
# 0                     0.007482
# 1                     0.005806
#
#                                     retrieval_result  \
# 0  [พระราชบัญญัติขายตรงและตลาดแบบตรง พ.ศ. 2545\n\...
# 1  [ประมวลกฎหมายแพ่งและพาณิชย์ - บรรพ 2 (หนี้) - ...
#
#                            retrieval_reranking_score  retrieval_time_usage  \
# 0  [0.9999263140701885, 1.3184367302834308e-06, 7...              0.420751
# 1  [0.9999997654566101, 0.004663654952382039, 0.0...              0.466929
#
#                                    generation_result  generation_time_usage
# 0  ตามพระราชบัญญัติขายตรงและตลาดแบบตรง พ.ศ. 2545 ...              44.161476
# 1                    ลูกหนี้สามารถชำระหนี้ได้โดยพลัน              55.262590

# %%
len(result_df['retrieval_result'].iloc[0])
# Out:
# 5

# %%
result_df.to_csv(INFERENCE_RESULT_PATH, index=False, encoding='utf-8')

# %%
INFERENCE_RESULT_PATH
# Out:
# '/project/lt200301-edubot/Capstone-TamTanai/inference_result/inference_end_to_end_n_documents=1.csv'

# %% [markdown]
# # Exam

# %%
exam_df = pd.read_csv('../asset/dataset/exam_test_data.csv')
exam_df
# Out:
#     Unnamed: 0                                           question  \
# 0            0  คําถาม: นายอาทิตย์ ทนายความถูกคณะกรรมการสภาทนา...
# 1            1  คําถาม: คำให้การของจำเลยข้อใดถือว่าจำเลยยอมรับ...
# 2            2  คําถาม: ข้อใดไม่เป็นคำสั่งระหว่างพิจารณาในคดีอ...
# 3            3  คําถาม: ในวันนัดสืบพยานโจทก์ จำเลยซึ่งขาดนัดยื...
# 4            4  คําถาม: การกำหนดวันนัดของศาลแขวงในคดีแพ่งไม่มี...
# ..         ...                                                ...
# 75          75  คําถาม: โจทก์ฟ้องว่าโจทก์เป็นเจ้าของที่ดินตามห...
# 76          76  คําถาม: คดีอาญาเรื่องหนึ่ง ศาลชั้นต้นพิพากษายก...
# 77          77  คําถาม: นายทองไม่ทราบถึงการที่โจทก์ฟ้องตนไปเพร...
# 78          78  คําถาม: ความผิดมูลฐานตามพระราชบัญญัติป้องกันแล...
# 79          79  คําถาม: การดำเนินการของบริษัทในข้อใดต่อไปนี้ ห...
#
#                                                answer  \
# 0   (4) มีความผิดทางอาญาต้องระวางโทษจำคุกไม่เกิน 2...
# 1   (3) จำเลยให้การต่อสู้ว่าโจทก์ไม่มีอำนาจฟ้องเพร...
# 2   (1) คำสั่งไม่อนุญาตให้ผู้เสียหายเข้าร่วมเป็นโจ...
# 3   (1) เป็นคำสั่งการดำเนินกระบวนพิจารณาที่ผิดระเบ...
# 4                                   (3) นัดชี้สองสถาน
# ..                                                ...
# 75  (2)ที่ดินพิพาทเป็นของโจทก์หรือไม่ ภาระการพิสูจ...
# 76                                          (2)15 วัน
# 77  (1)ร้องขอให้ศาลชั้นต้นเพิกถอนกระบวนพิจารณาได้ ...
# 78  (1)หมายถึงความผิดอาญาบางประเภทที่บัญญัติไว้ในม...
# 79                       (3)การถอดถอนกรรมการของบริษัท
#
#                                                prompt
# 0   <s><|im_start|>system\nคุณคือนักกฎหมายจงตอบคํา...
# 1   <s><|im_start|>system\nคุณคือนักกฎหมายจงตอบคํา...
# 2   <s><|im_start|>system\nคุณคือนักกฎหมายจงตอบคํา...
# 3   <s><|im_start|>system\nคุณคือนักกฎหมายจงตอบคํา...
# 4   <s><|im_start|>system\nคุณคือนักกฎหมายจงตอบคํา...
# ..                                                ...
# 75  <s><|im_start|>system\nคุณคือนักกฎหมายจงตอบคํา...
# 76  <s><|im_start|>system\nคุณคือนักกฎหมายจงตอบคํา...
# 77  <s><|im_start|>system\nคุณคือนักกฎหมายจงตอบคํา...
# 78  <s><|im_start|>system\nคุณคือนักกฎหมายจงตอบคํา...
# 79  <s><|im_start|>system\nคุณคือนักกฎหมายจงตอบคํา...
#
# [80 rows x 4 columns]

# %%
print(exam_df['question'][0])
# Out:
# คําถาม: นายอาทิตย์ ทนายความถูกคณะกรรมการสภาทนายความมีคำสั่งห้ามทำการเป็นทนายความมีกำหนด 2 ปี นายอาทิตย์ได้รับทราบคำสั่งเมื่อวันที่ 1 สิงหา 2553 และได้ยื่นอุทธรณ์คำสั่งต่อสภานายกพิเศษแห่งสภาทนายความเมื่อวันที่ 20 สิงหาคม 2553 ในระหว่างรอคำวินิจฉัยของสภานายกพิเศษแห่งสภาทนายความ นายอาทิตย์ ตกลงทำหน้าที่ทนายความให้แก่นางศุกร์ และทำคำร้องขอจัดการมรดกยื่นต่อศาลแพ่ง การกระทำของนายอาทิตย์ ผิดหรือไม่อย่างไร
#
# ตัวเลือก:
# (1) ไม่มีความผิดใด เพราะคดียังไม่ถึงที่สุด จึงยังสามารถทำหน้าที่ทนายความได้ต่อไปจนกว่าจะมีคำสั่งของสภานายกพิเศษแห่งสภาทนายความ
# (2) มีความผิดทางอาญา ต้องระวางโทษจำคุกไม่เกิน 4 ปี ปรับไม่เกิน 40,000 บาท หรือทั้งจำทั้งปรับ
# (3) ไม่มีความผิดทางอาญาและเป็นการละเมิดอำนาจศาล
# (4) มีความผิดทางอาญาต้องระวางโทษจำคุกไม่เกิน 2 ปี หรือปรับไม่เกิน 40,000 บาท หรือทั้งจำทั้งปรับ
